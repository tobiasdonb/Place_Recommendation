# %%
import requests
import datetime 
import os 
import json

# %%
#sebelumnya saya sudah mendeklarasikan variabel berisi API key di os demi keamanan code
api_key = os.getenv("MAPS_API_KEY")
if api_key is None:
    raise ValueError("API key not found")

# %%
location_data = []

# %%
def get_place_coords(place_name, api_key):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        'address': place_name,
        'key': api_key
    }
    res = requests.get(url, params=params)
    data = res.json()

    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        area = data['results'][0]['formatted_address']
        place_data = {
            'place_name': place_name,
            'latitude': location['lat'],
            'longitude': location['lng'],
            'area': area
        }
        if place_data not in location_data:
            location_data.append(place_data)
        else:
            None
            
        return place_data
    else:
        return None

# %%
get_place_coords('MCD SANUR',api_key)
# Out:
# {'place_name': 'MCD SANUR',
#  'latitude': -8.6825529,
#  'longitude': 115.2594186,
#  'area': 'Jl. Bypass Ngurah Rai No.109, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'}

# %%
get_place_coords('PLAZA RENON',api_key)
# Out:
# {'place_name': 'PLAZA RENON',
#  'latitude': -8.6732605,
#  'longitude': 115.244127,
#  'area': 'Jl. Raya Puputan No.210, Renon, Kec. Denpasar Tim., Kota Denpasar, Bali 80239, Indonesia'}

# %%
location_data
# Out:
# [{'place_name': 'MCD SANUR',
#   'latitude': -8.6825529,
#   'longitude': 115.2594186,
#   'area': 'Jl. Bypass Ngurah Rai No.109, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'place_name': 'PLAZA RENON',
#   'latitude': -8.6732605,
#   'longitude': 115.244127,
#   'area': 'Jl. Raya Puputan No.210, Renon, Kec. Denpasar Tim., Kota Denpasar, Bali 80239, Indonesia'}]

# %%
destination = []

# %%
#saya ingin download dan merapikan data json yang di crate API agar mudah saya baca
download_json = []

# %%
def search_nearby_place(location_data,radius_meters,type_place,api_key):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    #latitude dan longitude centroid berdasarkan rata2 latitude dan longitude
    #untuk mencari titik tengah dari lokasi-lokasi yang kita masukkan,terinsiprasi dari k means clustering
    all_latitude = [place['latitude'] for place in location_data]
    all_longitude = [place['longitude'] for place in location_data]

    lat_centroid = sum(all_latitude)/len(all_latitude)
    lng_centroid = sum(all_longitude)/len(all_longitude)
    
    params = {
        "location": f"{lat_centroid},{lng_centroid}",
        "radius": radius_meters,
        "type": type_place,
        "key": api_key
    }
  

    res = requests.get(url, params=params)
    data = res.json()

    #ARSIP
    # return data
    
    #sebelum lanjut membuat code untuk menambahkan data ke variabel destination,saya akan coba download file json/var datanya
    #bertujuan agar saya dapat melihat struktur data agar mudah dirapikan dan dimasukan ke variable destination
    # download_json.append(data)
    
    #setelah download data dan melihat struktur data json,saya lanjut mengambil 3 parameter utama berdasar struktur json yang sudah saya baca
    place_data = [{
        "place_name":place['name'],
        "latitude": place['geometry']['location']['lat'],
        "longitude": place['geometry']['location']['lng'],
        "rating": place.get('rating',0)
    } for place in data['results']]
    
    if place_data not in destination:
        destination.append(place_data)
    else:
        None
    
    return place_data

# %%
#tadi kan destination variable itu list dalam list krna saya loop pakai list comprehension,jadi saya flatten
destination_flatten = destination[0]

# %%
search_nearby_place(location_data,4000,'hospital',api_key)
# Out:
# [{'place_name': 'Global Health Center',
#   'latitude': -8.6885798,
#   'longitude': 115.2589453,
#   'rating': 4.8},
#  {'place_name': 'Bali Mandara Regional General Hospital',
#   'latitude': -8.7035694,
#   'longitude': 115.2487979,
#   'rating': 4},
#  {'place_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'latitude': -8.669945799999999,
#   'longitude': 115.2240217,
#   'rating': 3.7},
#  {'place_name': 'Darma Usadha Public Hospital',
#   'latitude': -8.668299799999998,
#   'longitude': 115.2184188,
#   'rating': 3},
#  {'place_name': 'RUMAH SAKIT Udayana',
#   'latitude': -8.663461900000001,
#   'longitude': 115.2194491,
#   'rating': 4.6},
#  {'place_name': 'Bali Royal Hospital',
#   'latitude': -8.6683921,
#   'longitude': 115.2277461,
#   'rating': 4},
#  {'place_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'latitude': -8.676269999999999,
#   'longitude': 115.2564565,
#   'rating': 4.8},
#  {'place_name': 'Doctor Surya Associates',
#   'latitude': -8.6772119,
#   'longitude': 115.2586608,
#   'rating': 5},
#  {'place_name': 'Bali International Hospital (Emergency Entrance)',
#   'latitude': -8.6790429,
#   'longitude': 115.2591727,
#   'rating': 4.6},
#  {'place_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'latitude': -8.6726145,
#   'longitude': 115.2583237,
#   'rating': 0},
#  {'place_name': 'Health Screening Bali International Hospital',
#   'latitude': -8.679480500000002,
#   'longitude': 115.2605972,
#   'rating': 3},
#  {'place_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'latitude': -8.6796052,
#   'longitude': 115.2606906,
#   'rating': 4.1},
#  {'place_name': 'Klinik Kanaka Medika',
#   'latitude': -8.6830196,
#   'longitude': 115.2594013,
#   'rating': 4.7},
#  {'place_name': 'Bluecross Medika Internasional',
#   'latitude': -8.6793688,
#   'longitude': 115.2619578,
#   'rating': 5},
#  {'place_name': 'IMUTS Baby Spa RENON',
#   'latitude': -8.674423899999999,
#   'longitude': 115.2414117,
#   'rating': 5},
#  {'place_name': 'M Arthen Kaadja pengobatan tradisional',
#   'latitude': -8.6835097,
#   'longitude': 115.241349,
#   'rating': 0},
#  {'place_name': 'Darmesta Internusa. PT',
#   'latitude': -8.6666432,
#   'longitude': 115.2550544,
#   'rating': 0},
#  {'place_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'latitude': -8.6736796,
#   'longitude': 115.2407047,
#   'rating': 4.9},
#  {'place_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'latitude': -8.688845599999999,
#   'longitude': 115.2580412,
#   'rating': 0},
#  {'place_name': 'Main Lobby Business Office',
#   'latitude': -8.6900961,
#   'longitude': 115.2570869,
#   'rating': 0}]

# %%
#ARSIP

# with open("nearby_search.json","w") as f:
#         json.dump(download_json,f)
# download_json.clear()

# %%
destination
# Out:
# [[{'place_name': 'Global Health Center',
#    'latitude': -8.6885798,
#    'longitude': 115.2589453,
#    'rating': 4.8},
#   {'place_name': 'Bali Mandara Regional General Hospital',
#    'latitude': -8.7035694,
#    'longitude': 115.2487979,
#    'rating': 4},
#   {'place_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#    'latitude': -8.669945799999999,
#    'longitude': 115.2240217,
#    'rating': 3.7},
#   {'place_name': 'Darma Usadha Public Hospital',
#    'latitude': -8.668299799999998,
#    'longitude': 115.2184188,
#    'rating': 3},
#   {'place_name': 'RUMAH SAKIT Udayana',
#    'latitude': -8.663461900000001,
#    'longitude': 115.2194491,
#    'rating': 4.6},
#   {'place_name': 'Bali Royal Hospital',
#    'latitude': -8.6683921,
#    'longitude': 115.2277461,
#    'rating': 4},
#   {'place_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#    'latitude': -8.676269999999999,
#    'longitude': 115.2564565,
#    'rating': 4.8},
#   {'place_name': 'Doctor Surya Associates',
#    'latitude': -8.6772119,
#    'longitude': 115.2586608,
#    'rating': 5},
#   {'place_name': 'Bali International Hospital (Emergency Entrance)',
#    'latitude': -8.6790429,
#    'longitude': 115.2591727,
#    'rating': 4.6},
#   {'place_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#    'latitude': -8.6726145,
#    'longitude': 115.2583237,
#    'rating': 0},
#   {'place_name': 'Health Screening Bali International Hospital',
#    'latitude': -8.679480500000002,
#    'longitude': 115.2605972,
#    'rating': 3},
#   {'place_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#    'latitude': -8.6796052,
#    'longitude': 115.2606906,
#    'rating': 4.1},
#   {'place_name': 'Klinik Kanaka Medika',
#    'latitude': -8.6830196,
#    'longitude': 115.2594013,
#    'rating': 4.7},
#   {'place_name': 'Bluecross Medika Internasional',
#    'latitude': -8.6793688,
#    'longitude': 115.2619578,
#    'rating': 5},
#   {'place_name': 'IMUTS Baby Spa RENON',
#    'latitude': -8.674423899999999,
#    'longitude': 115.2414117,
#    'rating': 5},
#   {'place_name': 'M Arthen Kaadja pengobatan tradisional',
#    'latitude': -8.6835097,
#    'longitude': 115.241349,
#    'rating': 0},
#   {'place_name': 'Darmesta Internusa. PT',
#    'latitude': -8.6666432,
#    'longitude': 115.2550544,
#    'rating': 0},
#   {'place_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#    'latitude': -8.6736796,
#    'longitude': 115.2407047,
#    'rating': 4.9},
#   {'place_name': 'KT. DianErlyyawati, S.KM,Akp.',
#    'latitude': -8.688845599999999,
#    'longitude': 115.2580412,
#    'rating': 0},
#   {'place_name': 'Main Lobby Business Office',
#    'latitude': -8.6900961,
#    'longitude': 115.2570869,
#    'rating': 0}]]

# %%
travel_time= []

# %%
def get_travel_time(location_data,destination_flatten,departure_time,api_key):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"n
    # for sublist in destination:
    #     destination_flattten.extend(sublist)
    #format untuk latitude longitude ke google api menggunakan |
    origin = "|".join([f"{o['latitude']},{o['longitude']}" for o in location_data])
    destination_coor = "|".join([f"{d['latitude']},{d['longitude']}" for d in destination_flattten])
    params = {
        "origins":origin,   
        "destinations":destination_coor,
        "mode":"driving",
        "departure_time":departure_time,
        "key":api_key
    }
    res = requests.get(url,params=params)
    data = res.json()

    #ARSIP
    
    #sebelum lanjut membuat code untuk menambahkan data ke variabel travel_time,saya akan coba download file json/var datanya
    #bertujuan agar saya dapat melihat struktur data agar mudah dirapikan dan dimasukan ke variable travel_time
    # download_json.append(data)

# merapikan variabel data,menam
    for i, row in enumerate(data['rows']):
        origin_name = location_data[i]['place_name']
        for j,element in enumerate(row['elements']):
            destination_name = destination_flattten[j]['place_name']
            alamat = data['destination_addresses'][j]
            durations= element['duration_in_traffic']['value']
            distance_in_meters = element['distance']['value']
            travel_time.append({
                "origin_name":origin_name,
                "destination_name":destination_name,
                "durations_in_seconds":durations,
                "distance_in_meters":distance_in_meters,
                "alamat":alamat
            })

# %%
get_travel_time(location_data,destination,'now',api_key)

# %%
#Arsip
# with open("distance_matrix.json","w") as f:
#         json.dump(download_json,f)
# download_json.clear()

# %%
travel_time
# Out:
# [{'origin_name': 'MCD SANUR',
#   'destination_name': 'Global Health Center',
#   'durations_in_seconds': 131,
#   'distance_in_meters': 726,
#   'alamat': 'Jl. Bypass Ngurah Rai No.178, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali Mandara Regional General Hospital',
#   'durations_in_seconds': 624,
#   'distance_in_meters': 4673,
#   'alamat': 'Jl. Bypass Ngurah Rai No.548, Sanur Kauh, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'durations_in_seconds': 835,
#   'distance_in_meters': 5232,
#   'alamat': 'Jl. Tantular Barat No.45, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Darma Usadha Public Hospital',
#   'durations_in_seconds': 1095,
#   'distance_in_meters': 6765,
#   'alamat': 'Jl. PB Sudirman No. 50 Denpasar Dauh Puri Klod%2FKelod Denpasar Barat Denpasar Bali, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'RUMAH SAKIT Udayana',
#   'durations_in_seconds': 1207,
#   'distance_in_meters': 7353,
#   'alamat': 'Jl. P.B. Sudirman No.1, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali Royal Hospital',
#   'durations_in_seconds': 854,
#   'distance_in_meters': 5045,
#   'alamat': 'Jl. Banteng Baru No.8, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'durations_in_seconds': 326,
#   'distance_in_meters': 1599,
#   'alamat': 'Jl. Danau Beratan No.12, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Doctor Surya Associates',
#   'durations_in_seconds': 152,
#   'distance_in_meters': 665,
#   'alamat': 'Jl. Bypass Ngurah Rai Br. Anggar Kasih No.214, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali International Hospital (Emergency Entrance)',
#   'durations_in_seconds': 242,
#   'distance_in_meters': 1109,
#   'alamat': 'Jl. Bypass Ngurah Rai. 126 Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Jl. Bypass Ngurah Rai No.101, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'durations_in_seconds': 264,
#   'distance_in_meters': 1242,
#   'alamat': 'Jl. Bypass Ngurah Rai No.176, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Health Screening Bali International Hospital',
#   'durations_in_seconds': 309,
#   'distance_in_meters': 1304,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'durations_in_seconds': 294,
#   'distance_in_meters': 1367,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Klinik Kanaka Medika',
#   'durations_in_seconds': 53,
#   'distance_in_meters': 71,
#   'alamat': '8785+QP7, Jl. Bypass Ngurah Rai No.113, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bluecross Medika Internasional',
#   'durations_in_seconds': 320,
#   'distance_in_meters': 1544,
#   'alamat': 'Jl. Inna Grand Bali Beach No.58, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'IMUTS Baby Spa RENON',
#   'durations_in_seconds': 567,
#   'distance_in_meters': 3095,
#   'alamat': 'Jl. Tukad Balian No.10 Blok A, Renon, Denpasar Selatan, Denpasar City, Bali 80239, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'M Arthen Kaadja pengobatan tradisional',
#   'durations_in_seconds': 514,
#   'distance_in_meters': 2421,
#   'alamat': 'Jl. Tukad Oos No.4, Renon, Denpasar Selatan, Kota Denpasar, Bali 80226, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Darmesta Internusa. PT',
#   'durations_in_seconds': 326,
#   'distance_in_meters': 2014,
#   'alamat': '87M4+933, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80237, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'durations_in_seconds': 548,
#   'distance_in_meters': 3065,
#   'alamat': '86GR+G86, Jl. Raya Puputan, Renon, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'durations_in_seconds': 347,
#   'distance_in_meters': 2080,
#   'alamat': '8765+F4G, Gg. Soka, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Main Lobby Business Office',
#   'durations_in_seconds': 386,
#   'distance_in_meters': 2218,
#   'alamat': 'Icon Bali unit GF-11, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Global Health Center',
#   'durations_in_seconds': 697,
#   'distance_in_meters': 3793,
#   'alamat': 'Jl. Bypass Ngurah Rai No.178, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali Mandara Regional General Hospital',
#   'durations_in_seconds': 835,
#   'distance_in_meters': 5266,
#   'alamat': 'Jl. Bypass Ngurah Rai No.548, Sanur Kauh, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'durations_in_seconds': 325,
#   'distance_in_meters': 2611,
#   'alamat': 'Jl. Tantular Barat No.45, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Darma Usadha Public Hospital',
#   'durations_in_seconds': 578,
#   'distance_in_meters': 4143,
#   'alamat': 'Jl. PB Sudirman No. 50 Denpasar Dauh Puri Klod%2FKelod Denpasar Barat Denpasar Bali, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'RUMAH SAKIT Udayana',
#   'durations_in_seconds': 692,
#   'distance_in_meters': 4731,
#   'alamat': 'Jl. P.B. Sudirman No.1, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali Royal Hospital',
#   'durations_in_seconds': 344,
#   'distance_in_meters': 2424,
#   'alamat': 'Jl. Banteng Baru No.8, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'durations_in_seconds': 623,
#   'distance_in_meters': 1642,
#   'alamat': 'Jl. Danau Beratan No.12, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Doctor Surya Associates',
#   'durations_in_seconds': 663,
#   'distance_in_meters': 3600,
#   'alamat': 'Jl. Bypass Ngurah Rai Br. Anggar Kasih No.214, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali International Hospital (Emergency Entrance)',
#   'durations_in_seconds': 828,
#   'distance_in_meters': 2322,
#   'alamat': 'Jl. Bypass Ngurah Rai. 126 Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Jl. Bypass Ngurah Rai No.101, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'durations_in_seconds': 782,
#   'distance_in_meters': 1970,
#   'alamat': 'Jl. Bypass Ngurah Rai No.176, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Health Screening Bali International Hospital',
#   'durations_in_seconds': 895,
#   'distance_in_meters': 2518,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'durations_in_seconds': 880,
#   'distance_in_meters': 2580,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Klinik Kanaka Medika',
#   'durations_in_seconds': 615,
#   'distance_in_meters': 3138,
#   'alamat': '8785+QP7, Jl. Bypass Ngurah Rai No.113, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bluecross Medika Internasional',
#   'durations_in_seconds': 907,
#   'distance_in_meters': 2757,
#   'alamat': 'Jl. Inna Grand Bali Beach No.58, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'IMUTS Baby Spa RENON',
#   'durations_in_seconds': 63,
#   'distance_in_meters': 474,
#   'alamat': 'Jl. Tukad Balian No.10 Blok A, Renon, Denpasar Selatan, Denpasar City, Bali 80239, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'M Arthen Kaadja pengobatan tradisional',
#   'durations_in_seconds': 314,
#   'distance_in_meters': 1591,
#   'alamat': 'Jl. Tukad Oos No.4, Renon, Denpasar Selatan, Kota Denpasar, Bali 80226, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Darmesta Internusa. PT',
#   'durations_in_seconds': 848,
#   'distance_in_meters': 2742,
#   'alamat': '87M4+933, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80237, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'durations_in_seconds': 45,
#   'distance_in_meters': 444,
#   'alamat': '86GR+G86, Jl. Raya Puputan, Renon, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'durations_in_seconds': 697,
#   'distance_in_meters': 3627,
#   'alamat': '8765+F4G, Gg. Soka, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Main Lobby Business Office',
#   'durations_in_seconds': 736,
#   'distance_in_meters': 3764,
#   'alamat': 'Icon Bali unit GF-11, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Global Health Center',
#   'durations_in_seconds': 130,
#   'distance_in_meters': 726,
#   'alamat': 'Jl. Bypass Ngurah Rai No.178, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali Mandara Regional General Hospital',
#   'durations_in_seconds': 636,
#   'distance_in_meters': 4673,
#   'alamat': 'Jl. Bypass Ngurah Rai No.548, Sanur Kauh, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'durations_in_seconds': 829,
#   'distance_in_meters': 5232,
#   'alamat': 'Jl. Tantular Barat No.45, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Darma Usadha Public Hospital',
#   'durations_in_seconds': 1090,
#   'distance_in_meters': 6765,
#   'alamat': 'Jl. PB Sudirman No. 50 Denpasar Dauh Puri Klod%2FKelod Denpasar Barat Denpasar Bali, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'RUMAH SAKIT Udayana',
#   'durations_in_seconds': 1197,
#   'distance_in_meters': 7353,
#   'alamat': 'Jl. P.B. Sudirman No.1, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali Royal Hospital',
#   'durations_in_seconds': 848,
#   'distance_in_meters': 5045,
#   'alamat': 'Jl. Banteng Baru No.8, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'durations_in_seconds': 319,
#   'distance_in_meters': 1460,
#   'alamat': 'Jl. Danau Beratan No.12, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Doctor Surya Associates',
#   'durations_in_seconds': 151,
#   'distance_in_meters': 665,
#   'alamat': 'Jl. Bypass Ngurah Rai Br. Anggar Kasih No.214, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali International Hospital (Emergency Entrance)',
#   'durations_in_seconds': 242,
#   'distance_in_meters': 1109,
#   'alamat': 'Jl. Bypass Ngurah Rai. 126 Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Jl. Bypass Ngurah Rai No.101, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'durations_in_seconds': 255,
#   'distance_in_meters': 1242,
#   'alamat': 'Jl. Bypass Ngurah Rai No.176, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Health Screening Bali International Hospital',
#   'durations_in_seconds': 309,
#   'distance_in_meters': 1304,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'durations_in_seconds': 294,
#   'distance_in_meters': 1367,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Klinik Kanaka Medika',
#   'durations_in_seconds': 52,
#   'distance_in_meters': 71,
#   'alamat': '8785+QP7, Jl. Bypass Ngurah Rai No.113, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Bluecross Medika Internasional',
#   'durations_in_seconds': 320,
#   'distance_in_meters': 1544,
#   'alamat': 'Jl. Inna Grand Bali Beach No.58, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'IMUTS Baby Spa RENON',
#   'durations_in_seconds': 565,
#   'distance_in_meters': 3095,
#   'alamat': 'Jl. Tukad Balian No.10 Blok A, Renon, Denpasar Selatan, Denpasar City, Bali 80239, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'M Arthen Kaadja pengobatan tradisional',
#   'durations_in_seconds': 516,
#   'distance_in_meters': 2421,
#   'alamat': 'Jl. Tukad Oos No.4, Renon, Denpasar Selatan, Kota Denpasar, Bali 80226, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Darmesta Internusa. PT',
#   'durations_in_seconds': 310,
#   'distance_in_meters': 2014,
#   'alamat': '87M4+933, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80237, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'durations_in_seconds': 545,
#   'distance_in_meters': 3065,
#   'alamat': '86GR+G86, Jl. Raya Puputan, Renon, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'durations_in_seconds': 354,
#   'distance_in_meters': 2080,
#   'alamat': '8765+F4G, Gg. Soka, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'MCD SANUR',
#   'destination_name': 'Main Lobby Business Office',
#   'durations_in_seconds': 391,
#   'distance_in_meters': 2218,
#   'alamat': 'Icon Bali unit GF-11, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Global Health Center',
#   'durations_in_seconds': 724,
#   'distance_in_meters': 3384,
#   'alamat': 'Jl. Bypass Ngurah Rai No.178, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali Mandara Regional General Hospital',
#   'durations_in_seconds': 816,
#   'distance_in_meters': 5266,
#   'alamat': 'Jl. Bypass Ngurah Rai No.548, Sanur Kauh, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'durations_in_seconds': 326,
#   'distance_in_meters': 2611,
#   'alamat': 'Jl. Tantular Barat No.45, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Darma Usadha Public Hospital',
#   'durations_in_seconds': 584,
#   'distance_in_meters': 4143,
#   'alamat': 'Jl. PB Sudirman No. 50 Denpasar Dauh Puri Klod%2FKelod Denpasar Barat Denpasar Bali, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'RUMAH SAKIT Udayana',
#   'durations_in_seconds': 698,
#   'distance_in_meters': 4731,
#   'alamat': 'Jl. P.B. Sudirman No.1, Dauh Puri, Kec. Denpasar Bar., Kota Denpasar, Bali 80232, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali Royal Hospital',
#   'durations_in_seconds': 344,
#   'distance_in_meters': 2424,
#   'alamat': 'Jl. Banteng Baru No.8, Dangin Puri Klod, Kec. Denpasar Tim., Kota Denpasar, Bali 80234, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'durations_in_seconds': 408,
#   'distance_in_meters': 1642,
#   'alamat': 'Jl. Danau Beratan No.12, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Doctor Surya Associates',
#   'durations_in_seconds': 589,
#   'distance_in_meters': 2382,
#   'alamat': 'Jl. Bypass Ngurah Rai Br. Anggar Kasih No.214, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali International Hospital (Emergency Entrance)',
#   'durations_in_seconds': 568,
#   'distance_in_meters': 2322,
#   'alamat': 'Jl. Bypass Ngurah Rai. 126 Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Jl. Bypass Ngurah Rai No.101, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'durations_in_seconds': 521,
#   'distance_in_meters': 1970,
#   'alamat': 'Jl. Bypass Ngurah Rai No.176, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Health Screening Bali International Hospital',
#   'durations_in_seconds': 634,
#   'distance_in_meters': 2518,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'durations_in_seconds': 619,
#   'distance_in_meters': 2580,
#   'alamat': 'Jalan Kawasan Ekonomi Khusus Sanur, Lot H1-H2, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Klinik Kanaka Medika',
#   'durations_in_seconds': 645,
#   'distance_in_meters': 2728,
#   'alamat': '8785+QP7, Jl. Bypass Ngurah Rai No.113, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Bluecross Medika Internasional',
#   'durations_in_seconds': 646,
#   'distance_in_meters': 2757,
#   'alamat': 'Jl. Inna Grand Bali Beach No.58, Sanur Kaja, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'IMUTS Baby Spa RENON',
#   'durations_in_seconds': 65,
#   'distance_in_meters': 474,
#   'alamat': 'Jl. Tukad Balian No.10 Blok A, Renon, Denpasar Selatan, Denpasar City, Bali 80239, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'M Arthen Kaadja pengobatan tradisional',
#   'durations_in_seconds': 289,
#   'distance_in_meters': 1591,
#   'alamat': 'Jl. Tukad Oos No.4, Renon, Denpasar Selatan, Kota Denpasar, Bali 80226, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Darmesta Internusa. PT',
#   'durations_in_seconds': 578,
#   'distance_in_meters': 2742,
#   'alamat': '87M4+933, Sanur Kaja, Denpasar Selatan, Denpasar City, Bali 80237, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'durations_in_seconds': 46,
#   'distance_in_meters': 444,
#   'alamat': '86GR+G86, Jl. Raya Puputan, Renon, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'durations_in_seconds': 669,
#   'distance_in_meters': 3627,
#   'alamat': '8765+F4G, Gg. Soka, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Main Lobby Business Office',
#   'durations_in_seconds': 705,
#   'distance_in_meters': 3764,
#   'alamat': 'Icon Bali unit GF-11, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80228, Indonesia'}]

# %%
destination_flatten
# Out:
# [{'place_name': 'Global Health Center',
#   'latitude': -8.6885798,
#   'longitude': 115.2589453,
#   'rating': 4.8},
#  {'place_name': 'Bali Mandara Regional General Hospital',
#   'latitude': -8.7035694,
#   'longitude': 115.2487979,
#   'rating': 4},
#  {'place_name': 'Rumah Sakit Ibu & Anak Bali Royal (RSIA Bali Royal)',
#   'latitude': -8.669945799999999,
#   'longitude': 115.2240217,
#   'rating': 3.7},
#  {'place_name': 'Darma Usadha Public Hospital',
#   'latitude': -8.668299799999998,
#   'longitude': 115.2184188,
#   'rating': 3},
#  {'place_name': 'RUMAH SAKIT Udayana',
#   'latitude': -8.663461900000001,
#   'longitude': 115.2194491,
#   'rating': 4.6},
#  {'place_name': 'Bali Royal Hospital',
#   'latitude': -8.6683921,
#   'longitude': 115.2277461,
#   'rating': 4},
#  {'place_name': 'Klinik Anger Kasih dr. Eka Rahayu Dewi',
#   'latitude': -8.676269999999999,
#   'longitude': 115.2564565,
#   'rating': 4.8},
#  {'place_name': 'Doctor Surya Associates',
#   'latitude': -8.6772119,
#   'longitude': 115.2586608,
#   'rating': 5},
#  {'place_name': 'Bali International Hospital (Emergency Entrance)',
#   'latitude': -8.6790429,
#   'longitude': 115.2591727,
#   'rating': 4.6},
#  {'place_name': 'Drg. Ade Agus Indra Yoga | ADentist Dental Clinic',
#   'latitude': -8.6726145,
#   'longitude': 115.2583237,
#   'rating': 0},
#  {'place_name': 'Health Screening Bali International Hospital',
#   'latitude': -8.679480500000002,
#   'longitude': 115.2605972,
#   'rating': 3},
#  {'place_name': 'Bali International Hospital (Main Lobby and MCU Entrance)',
#   'latitude': -8.6796052,
#   'longitude': 115.2606906,
#   'rating': 4.1},
#  {'place_name': 'Klinik Kanaka Medika',
#   'latitude': -8.6830196,
#   'longitude': 115.2594013,
#   'rating': 4.7},
#  {'place_name': 'Bluecross Medika Internasional',
#   'latitude': -8.6793688,
#   'longitude': 115.2619578,
#   'rating': 5},
#  {'place_name': 'IMUTS Baby Spa RENON',
#   'latitude': -8.674423899999999,
#   'longitude': 115.2414117,
#   'rating': 5},
#  {'place_name': 'M Arthen Kaadja pengobatan tradisional',
#   'latitude': -8.6835097,
#   'longitude': 115.241349,
#   'rating': 0},
#  {'place_name': 'Darmesta Internusa. PT',
#   'latitude': -8.6666432,
#   'longitude': 115.2550544,
#   'rating': 0},
#  {'place_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'latitude': -8.6736796,
#   'longitude': 115.2407047,
#   'rating': 4.9},
#  {'place_name': 'KT. DianErlyyawati, S.KM,Akp.',
#   'latitude': -8.688845599999999,
#   'longitude': 115.2580412,
#   'rating': 0},
#  {'place_name': 'Main Lobby Business Office',
#   'latitude': -8.6900961,
#   'longitude': 115.2570869,
#   'rating': 0}]

# %%
fastest_place = {}

for data in travel_time:
    name = data['origin_name']
    distance_in_meters = data['distance_in_meters']
    if name not in fastest_place or distance_in_meters < fastest_place[name]['distance_in_meters']:
        fastest_place[name] = data
fastest_place_arr = list(fastest_place.values())

# %%
fastest_place_arr
# Out:
# [{'origin_name': 'MCD SANUR',
#   'destination_name': 'Klinik Kanaka Medika',
#   'durations_in_seconds': 53,
#   'distance_in_meters': 71,
#   'alamat': '8785+QP7, Jl. Bypass Ngurah Rai No.113, Sanur, Denpasar Selatan, Kota Denpasar, Bali 80227, Indonesia'},
#  {'origin_name': 'PLAZA RENON',
#   'destination_name': 'Frejus Clinic Bali ( Jasper Skincare )',
#   'durations_in_seconds': 45,
#   'distance_in_meters': 444,
#   'alamat': '86GR+G86, Jl. Raya Puputan, Renon, Denpasar Selatan, Kota Denpasar, Bali, Indonesia'}]

# %%
def search_byrating(destination):
    max_rating = 0
    for i in destination_flatten:
        current_state = i.get("rating", 0)
        if current_state > max_rating:
            max_rating = current_state

    top_places = []
    for x in destination_flatten:
        if x.get("rating", 0) == max_rating:
            top_places.append(x)

    print(f"Rating Tertinggi Ditemukan: {max_rating}")
    print("Daftar Tempat dengan Rating Tersebut:\n")
    for p in top_places:
        print(f"{p.get('place_name')} : rating {p.get('rating')}")

# %%
search_byrating(destination_flatten)
# Out:
# Rating Tertinggi Ditemukan: 5
# Daftar Tempat dengan Rating Tersebut:
#
# Doctor Surya Associates : rating 5
# Bluecross Medika Internasional : rating 5
# IMUTS Baby Spa RENON : rating 5
